# %%
import pandas as pd

# %%
netf = pd.read_csv('netflix_titles/netflix_titles.csv')

# %%
netf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netf
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netf['release_year'].unique()

max_y = netf['release_year'].idxmax()
print(netf.loc[max_y]['release_year'])

min_y = netf["release_year"].idxmin()
print(netf.loc[min_y , "release_year"])

print(netf['release_year'].mean().astype(int))


print(netf["rating"].value_counts())
# Out:
# 2021
# 1925
# 2014
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
# # 11.
netf[netf["type"] == "Movie"]

# # 12.
netf[netf["type"] == "TV Show"]

# # 13.
netf[netf["country"].str.contains("India", na=False)]

# # 14.
netf[netf["country"].str.contains("United States", na=False)]

# 15.
netf[netf['release_year'] > 2018]

# 16.
netf[netf['rating'] == 'TV-MA']

# 17
netf["durTime"] = netf["duration"].str.extract(r"(\d+)").astype("Int64")
netf[(netf["type"] == "Movie") & (netf["durTime"] > 120)]

# 18.
netf[(netf['type'] == 'TV Show') & (netf['durTime'] > 3)]

# 19.
netf['date_addedN'] = pd.to_datetime(netf['date_added'].str.strip())
netf[netf['date_addedN'].dt.year == 2021]

# 20.
netf[netf['title'].str.contains('Love', case=False, na=False)]
# Out:
#      show_id     type                           title  \
# 25       s26  TV Show            Love on the Spectrum
# 158     s159    Movie         Love Don't Cost a Thing
# 159     s160    Movie                  Love in a Puff
# 206     s207    Movie       LSD: Love, Sex Aur Dhokha
# 227     s228    Movie                     Really Love
# ...      ...      ...                             ...
# 8567   s8568  TV Show  The Year of Happiness and Love
# 8575   s8576  TV Show                 This Is My Love
# 8649   s8650    Movie           Two Lovers and a Bear
# 8721   s8722  TV Show                   What Is Love?
# 8725   s8726    Movie            What's Up With Love?
#
#                        director  \
# 25                          NaN
# 158                   Troy Byer
# 159              Pang Ho-cheung
# 206            Dibakar Banerjee
# 227       Angel Kristi Williams
# ...                         ...
# 8567                        NaN
# 8575                        NaN
# ...

# %%
# 21.
netf['release_year'].value_counts().idxmax()

# 22.
netf['country'].value_counts().idxmax()

# 23.
netf['rating'].value_counts().idxmin()

# 24.
netf.loc[netf['title'].str.len().idxmax(), 'title']

# 25.
netf.loc[netf[netf['type'] == 'Movie']['durTime'].idxmin()]['title']

# 26.
netf.loc[netf[netf["type"] == "Movie"]["durTime"].idxmax()]["title"]

# 27.
netf['director'].value_counts().idxmax()

# 28.
netf['cast'].str.split(',').explode().value_counts().idxmax()

# 29.
netf['listed_in'].str.split(',').explode().value_counts().idxmax()

# 30.
netf['date_addedN'].dt.year.astype('Int64').value_counts().idxmax()
# Out:
# 2019

# %%
# 1.
netf[netf['country'].str.contains('India', na=False)]['cast'].str.split(',').explode().value_counts().idxmax()

# 2.
netf[netf['type'] == 'Movie']['listed_in'].str.split(',').explode().str.strip().value_counts().idxmax()

# 4.
netf[netf['type'] == 'TV Show']['date_addedN'].dt.year.astype('Int64').value_counts().idxmax()

# 5.
netf.loc[netf['release_year'].idxmin(), ['title', 'date_added', 'release_year']]
# Out:
# 2020

# %%
netf.isna().sum()
# netf['director'].fillna('UnknownDirector', inplace=True)
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            825
# country         831
# date_added       10
# release_year      0
# rating            4
# duration          3
# listed_in         0
# description       0
# durTime           3
# date_addedN      10
# dtype: int64

# %%
netf['director']
# Out:
# 0       Kirsten Johnson
# 1       UnknownDirector
# 2       Julien Leclercq
# 3       UnknownDirector
# 4       UnknownDirector
#              ...
# 8802      David Fincher
# 8803    UnknownDirector
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
netf_10 = netf.loc[0:9]
netf_10.to_json('netflix_titles/data.json', orient='records',  indent=2)

# %%
import requests

base_url = "https://api.restcountries.com/countries/v5"

headers = {"Authorization": "Bearer rc_live_35e0adc91c594cbe906c38cd5d943e48"}

response3 = requests.get(base_url, headers=headers)

json_data = response3.json()

data = pd.json_normalize(json_data['data']['objects'])[['names.common', 'names.official' , 'region', 'currencies']].explode('currencies')

data.head()
# Out:
#      names.common                           names.official   region  \
# 0        Abkhazia                     Republic of Abkhazia     Asia
# 1     Afghanistan          Islamic Republic of Afghanistan     Asia
# 2         Albania                      Republic of Albania   Europe
# 3         Algeria  People's Democratic Republic of Algeria   Africa
# 4  American Samoa                           American Samoa  Oceania
#
#                                           currencies
# 0  {'code': 'RUB', 'name': 'Russian ruble', 'symb...
# 1  {'code': 'AFN', 'name': 'Afghan afghani', 'sym...
# 2  {'code': 'ALL', 'name': 'Albanian lek', 'symbo...
# 3  {'code': 'DZD', 'name': 'Algerian dinar', 'sym...
# 4  {'code': 'USD', 'name': 'United States dollar'...
